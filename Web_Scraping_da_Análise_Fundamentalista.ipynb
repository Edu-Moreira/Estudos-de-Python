# %% [markdown]
# #1. Obtendo dados cadastrais das empresas de capital aberto

# %%
import pandas as pd
import numpy as np
import requests

# %%
link = 'http://dados.cvm.gov.br/dados/CIA_ABERTA/CAD/DADOS/cad_cia_aberta.csv'

# %%
r = requests.get(link)

# %%
linhas = []

for i in r.text.split('\n'):
  linhas.append(i.strip().split(';'))

# %%
data = pd.DataFrame(linhas[1:], columns = linhas[0])

# %%
data.head()
# Out:
#              CNPJ_CIA  ...                                            AUDITOR
# 0  08.773.135/0001-00  ...          ERNST & YOUNG AUDITORES INDEPENDENTES S/S
# 1  11.396.633/0001-87  ...  MOORE STEPHENS LIMA LUCCHESI AUDITORES INDEPEN...
# 2  12.091.809/0001-55  ...                       KPMG AUDITORES INDEPENDENTES
# 3  01.547.749/0001-16  ...             GRANT THORNTON AUDITORES INDEPENDENTES
# 4  01.851.771/0001-55  ...             GRANT THORNTON AUDITORES INDEPENDENTES
#
# [5 rows x 47 columns]

# %%
lines = [i.strip().split(';') for i in r.text.split('\n')]

# %%
data = pd.DataFrame(lines[1:], columns = lines[0])

# %%
data.head()
# Out:
#              CNPJ_CIA  ...                                            AUDITOR
# 0  08.773.135/0001-00  ...          ERNST & YOUNG AUDITORES INDEPENDENTES S/S
# 1  11.396.633/0001-87  ...  MOORE STEPHENS LIMA LUCCHESI AUDITORES INDEPEN...
# 2  12.091.809/0001-55  ...                       KPMG AUDITORES INDEPENDENTES
# 3  01.547.749/0001-16  ...             GRANT THORNTON AUDITORES INDEPENDENTES
# 4  01.851.771/0001-55  ...             GRANT THORNTON AUDITORES INDEPENDENTES
#
# [5 rows x 47 columns]

# %%
searchfor = ['MULTIPLAN', 'MALL', 'IGUATEMI', 'SHOPP']
shoppings = data[data.DENOM_SOCIAL.str.contains('|'.join(searchfor), na = False)]

# %%
shoppings.head()
# Out:
#                CNPJ_CIA  ...                                         AUDITOR
# 65   06.082.980/0001-03  ...  PRICEWATERHOUSECOOPERS AUDITORES INDEPENDENTES
# 66   05.878.397/0001-32  ...  PRICEWATERHOUSECOOPERS AUDITORES INDEPENDENTES
# 103  00.979.769/0001-01  ...                                      RUHTRA S/C
# 354  06.977.745/0001-91  ...  PRICEWATERHOUSECOOPERS AUDITORES INDEPENDENTES
# 905  00.664.949/0001-96  ...                                      RUHTRA S/C
#
# [5 rows x 47 columns]

# %%
comercio = data[data['SETOR_ATIV'] == 'Comércio (Atacado e Varejo)']
comercio = comercio[comercio['SIT'] == 'ATIVO']

# %%
comercio.shape
# Out:
# (41, 47)

# %%
comercio.head()
# Out:
#                CNPJ_CIA  ...                                         AUDITOR
# 47   21.240.146/0001-84  ...  PRICEWATERHOUSECOOPERS AUDITORES INDEPENDENTES
# 70   20.247.322/0001-47  ...       ERNST & YOUNG AUDITORES INDEPENDENTES S/S
# 96   00.776.574/0001-56  ...                    KPMG AUDITORES INDEPENDENTES
# 701  12.420.164/0001-57  ...                    KPMG AUDITORES INDEPENDENTES
# 736  47.508.411/0001-56  ...       ERNST & YOUNG AUDITORES INDEPENDENTES S/S
#
# [5 rows x 47 columns]

# %%
shoppings_ativos = shoppings[shoppings['SIT'] == 'ATIVO']

# %%
shoppings_ativos.shape
# Out:
# (6, 47)

# %%
shoppings_ativos.head(3)
# Out:
#                 CNPJ_CIA  ...                                            AUDITOR
# 66    05.878.397/0001-32  ...     PRICEWATERHOUSECOOPERS AUDITORES INDEPENDENTES
# 354   06.977.745/0001-91  ...     PRICEWATERHOUSECOOPERS AUDITORES INDEPENDENTES
# 1156  08.764.621/0001-53  ...  BDO RCS AUDITORES INDEPENDENTES - SOCIEDADE SI...
#
# [3 rows x 47 columns]

# %%
list(shoppings_ativos['CD_CVM'])
# Out:
# ['22357', '19909', '21008', '20494', '24473', '20982']

# %%
empresas = list(shoppings_ativos['CD_CVM'])

# %% [markdown]
# ### outra opção para filtro: utilizando o CNPJ

# %%
lista_cnpjs = ['05.878.397/0001-32','08.294.224/0001-65', '07.816.890/0001-53', '51.218.147/0001-93', '06.977.751/0001-49']

# %%
jhsf = '08.294.224/0001-65'

# %%
jhsf_data = data[data['CNPJ_CIA'] == jhsf]

# %%
jhsf_data
# Out:
#                 CNPJ_CIA  ...                                    AUDITOR
# 1378  08.294.224/0001-65  ...  ERNST & YOUNG AUDITORES INDEPENDENTES S/S
#
# [1 rows x 47 columns]

# %%
filtrados = data[data['CNPJ_CIA'].isin(lista_cnpjs)]

# %%
filtrados
# Out:
#                 CNPJ_CIA  ...                                         AUDITOR
# 66    05.878.397/0001-32  ...  PRICEWATERHOUSECOOPERS AUDITORES INDEPENDENTES
# 355   06.977.751/0001-49  ...       ERNST & YOUNG AUDITORES INDEPENDENTES S/S
# 1244  51.218.147/0001-93  ...       ERNST & YOUNG AUDITORES INDEPENDENTES S/S
# 1378  08.294.224/0001-65  ...       ERNST & YOUNG AUDITORES INDEPENDENTES S/S
# 1629  07.816.890/0001-53  ...       ERNST & YOUNG AUDITORES INDEPENDENTES S/S
#
# [5 rows x 47 columns]

# %%
empresas = list(filtrados['CD_CVM'])

# %%
empresas
# Out:
# ['22357', '19925', '20494', '20605', '20982']

# %% [markdown]
# # 2. Extração dos demonstrativos trimestrais das empresas

# %%
import zipfile
import io

# %% [markdown]
# Quais demonstrativos você precisa?
#
# Em 'arquivo', determine o tipo de demonstrativo e o ano
#
# Esse 'arquivo' precisa estar contido na pasta zipada da CVM
#
# O 'arquivo' precisa estar na pasta zipada contida em 'link'

# %%
arquivo = 'itr_cia_aberta_DRE_con_2021.csv'
link = 'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/ITR/DADOS/itr_cia_aberta_2021.zip'

# %%
arquivo_zip = requests.get(link)

# %%
zf = zipfile.ZipFile(io.BytesIO(arquivo_zip.content))

# %%
zf
# Out:
# <zipfile.ZipFile file=<_io.BytesIO object at 0x7f01826249b0> mode='r'>

# %%
DRE = zf.open(arquivo)

# %%
linhas = DRE.readlines()

# %%
lines = [i.strip().decode('ISO-8859-1') for i in linhas]

# %%
lines = [i.split(';') for i in lines]

# %%
df = pd.DataFrame(lines[1:], columns = lines[0])

# %%
df.head(3)
# Out:
#              CNPJ_CIA    DT_REFER  ...             VL_CONTA ST_CONTA_FIXA
# 0  00.001.180/0001-26  2021-03-31  ...   7603566.0000000000             S
# 1  00.001.180/0001-26  2021-03-31  ...   8208426.0000000000             S
# 2  00.001.180/0001-26  2021-03-31  ...  -3042280.0000000000             S
#
# [3 rows x 15 columns]

# %%
df[df['CD_CVM'] == '019909']
# Out:
#                  CNPJ_CIA    DT_REFER  ...           VL_CONTA ST_CONTA_FIXA
# 14575  06.977.745/0001-91  2021-03-31  ...  283760.0000000000             S
# 14576  06.977.745/0001-91  2021-03-31  ...  230691.0000000000             S
# 14577  06.977.745/0001-91  2021-03-31  ...  -32153.0000000000             S
# 14578  06.977.745/0001-91  2021-03-31  ...  -26611.0000000000             S
# 14579  06.977.745/0001-91  2021-03-31  ...  251607.0000000000             S
# ...                   ...         ...  ...                ...           ...
# 14770  06.977.745/0001-91  2021-06-30  ...       0.0000000000             N
# 14771  06.977.745/0001-91  2021-06-30  ...      -0.5900000000             N
# 14772  06.977.745/0001-91  2021-06-30  ...      -0.5900000000             N
# 14773  06.977.745/0001-91  2021-06-30  ...       0.0000000000             N
# 14774  06.977.745/0001-91  2021-06-30  ...       0.0000000000             N
#
# [200 rows x 15 columns]

# %%
df.dtypes
# Out:
# CNPJ_CIA         object
# DT_REFER         object
# VERSAO           object
# DENOM_CIA        object
# CD_CVM           object
# GRUPO_DFP        object
# MOEDA            object
# ESCALA_MOEDA     object
# ORDEM_EXERC      object
# DT_INI_EXERC     object
# DT_FIM_EXERC     object
# CD_CONTA         object
# DS_CONTA         object
# VL_CONTA         object
# ST_CONTA_FIXA    object
# dtype: object

# %% [markdown]
# # 3. Criação de uma rotina de extração

# %%
df.DT_FIM_EXERC.unique()
# Out:
# array(['2020-03-31', '2021-03-31', '2020-06-30', '2021-06-30',
#        '2020-05-31', '2021-05-31'], dtype=object)

# %%
df.DT_REFER.unique()
# Out:
# array(['2021-03-31', '2021-06-30', '2021-05-31'], dtype=object)

# %% [markdown]
# ## Início da construção do loop

# %% [markdown]
# Vamos criar um loop que vai fazer a captura de vários demonstrativos de uma vez, e depois filtrar empresas específicas
#
# Quando isso for terminado, ele vai gerar um excel por empresa, onde cada aba será um demonstrativo diferente
#
# O usuário terá apenas que passar uma lista de empresas que deseja e também uma lista com demonstrativos

# %%
demonstrativos = ['DFC_MD', 'DFC_MI','BPA','DRE']

# %%
# !pip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.0.1-py3-none-any.whl (148 kB)
#      |████████████████████████████████| 148 kB 14.6 MB/s
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.0.1

# %%
import xlsxwriter

# %%
empresas
# Out:
# ['22357', '19925', '20494', '20605', '20982']

# %%
empresas.append('9512')

# %%
empresas
# Out:
# ['22357', '19925', '20494', '20605', '20982', '9512']

# %% [markdown]
# Link para demonstrativos trimestrais: http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/ITR/DADOS/itr_cia_aberta_2021.zip
#
# Link para demonstrativos anuais: http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2021.zip

# %% [markdown]
# Como adaptar o número de zeros corretamente caso o código da CVM tenha menos de 5 números?

# %%
j = '9512'

'00' + j
# Out:
# '009512'

# %%
j.zfill(6)
# Out:
# '009512'

# %%
import time
start_time = time.time()

import zipfile
import io

lista_listas = []

a = 0

for j in empresas:

  lista_df = []


  for k in demonstrativos:

    link = 'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/ITR/DADOS/itr_cia_aberta_2021.zip'

    arquivo_zip = requests.get(link)

    zf = zipfile.ZipFile(io.BytesIO(arquivo_zip.content))

    arquivo = 'itr_cia_aberta_' + str(k) + '_con_2021.csv'

    dados = zf.open(arquivo)

    linhas = dados.readlines()

    lines = [i.strip().decode('ISO-8859-1') for i in linhas]

    lines = [i.split(';') for i in lines]

    df = pd.DataFrame(lines[1:], columns = lines[0])

    df['VL_AJUSTADO'] = pd.to_numeric(df['VL_CONTA'])

    filtro = df[df['CD_CVM']== str(j).zfill(6)]

    lista_df.append(filtro)

    print(f'Trabalhando com a empresa {j} e seu demonstrativo {k}. As dimensões são {filtro.shape} ')

  lista_listas.append(lista_df)

  # Utilizando a biblioteca xlsxwriter
  writer = pd.ExcelWriter(f'Demonstrativos Empresa {str(j)}.xlsx', engine= 'xlsxwriter')

  # Especifique o que esse arquivo de Excel vai conter
  lista_listas[a][0].to_excel(writer, sheet_name = 'DFC_MD', encoding = 'ISO-8859-1')
  lista_listas[a][1].to_excel(writer, sheet_name = 'DFC_MI', encoding = 'ISO-8859-1')
  lista_listas[a][2].to_excel(writer, sheet_name = 'BPA', encoding = 'ISO-8859-1')
  lista_listas[a][3].to_excel(writer, sheet_name = 'DRE', encoding = 'ISO-8859-1')
  #lista_listas[a][4].to_excel(writer, sheet_name = 'BPP', encoding = 'ISO-8859-1')

  a += 1

  print(f'Arquivo Excel com os demonstrativos da empresa {str(j)} já foi exportado. \n')

  # Fechar o arquivo Excel
  writer.save()

print("O tempo de execução desse programa foi de %s segundos ---" %(time.time() -start_time))
# Out:
# Trabalhando com a empresa 22357 e seu demonstrativo DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 22357 e seu demonstrativo DFC_MI. As dimensões são (278, 16)
# Trabalhando com a empresa 22357 e seu demonstrativo BPA. As dimensões são (232, 15)
# Trabalhando com a empresa 22357 e seu demonstrativo DRE. As dimensões são (180, 16)
# Arquivo Excel com os demonstrativos da empresa 22357 já foi exportado.
#
# Trabalhando com a empresa 19925 e seu demonstrativo DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 19925 e seu demonstrativo DFC_MI. As dimensões são (248, 16)
# Trabalhando com a empresa 19925 e seu demonstrativo BPA. As dimensões são (256, 15)
# Trabalhando com a empresa 19925 e seu demonstrativo DRE. As dimensões são (234, 16)
# Arquivo Excel com os demonstrativos da empresa 19925 já foi exportado.
#
# Trabalhando com a empresa 20494 e seu demonstrativo DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 20494 e seu demonstrativo DFC_MI. As dimensões são (202, 16)
# Trabalhando com a empresa 20494 e seu demonstrativo BPA. As dimensões são (272, 15)
# Trabalhando com a empresa 20494 e seu demonstrativo DRE. As dimensões são (180, 16)
# Arquivo Excel com os demonstrativos da empresa 20494 já foi exportado.
#
# Trabalhando com a empresa 20605 e seu demonstrativo DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 20605 e seu demonstrativo DFC_MI. As dimensões são (184, 16)
# Trabalhando com a empresa 20605 e seu demonstrativo BPA. As dimensões são (260, 15)
# Trabalhando com a empresa 20605 e seu demonstrativo DRE. As dimensões são (252, 16)
# Arquivo Excel com os demonstrativos da empresa 20605 já foi exportado.
#
# Trabalhando com a empresa 20982 e seu demonstrativo DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 20982 e seu demonstrativo DFC_MI. As dimensões são (165, 16)
# Trabalhando com a empresa 20982 e seu demonstrativo BPA. As dimensões são (192, 15)
# Trabalhando com a empresa 20982 e seu demonstrativo DRE. As dimensões são (111, 16)
# Arquivo Excel com os demonstrativos da empresa 20982 já foi exportado.
#
# Trabalhando com a empresa 9512 e seu demonstrativo DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 9512 e seu demonstrativo DFC_MI. As dimensões são (186, 16)
# Trabalhando com a empresa 9512 e seu demonstrativo BPA. As dimensões são (195, 15)
# Trabalhando com a empresa 9512 e seu demonstrativo DRE. As dimensões são (129, 16)
# Arquivo Excel com os demonstrativos da empresa 9512 já foi exportado.
#
# O tempo de execução desse programa foi de 147.66670489311218 segundos ---

# %%
 lista_listas[1][3].head()
# Out:
#                  CNPJ_CIA    DT_REFER  ... ST_CONTA_FIXA VL_AJUSTADO
# 14775  06.977.751/0001-49  2021-03-31  ...             S     76010.0
# 14776  06.977.751/0001-49  2021-03-31  ...             S     82348.0
# 14777  06.977.751/0001-49  2021-03-31  ...             N     76010.0
# 14778  06.977.751/0001-49  2021-03-31  ...             N     82348.0
# 14779  06.977.751/0001-49  2021-03-31  ...             S         0.0
#
# [5 rows x 16 columns]
