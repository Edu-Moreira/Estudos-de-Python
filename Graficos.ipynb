# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
pip install --trusted-host pypi.org --trusted-host pypi.python.org --trusted-host files.pythonhosted.org nbformat
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
carteira = pd.DataFrame(pd.read_excel("Carteiras Simuladas.xlsx", index_col= 0 )['MinVol'])

carteira = (carteira/carteira.iloc[0])*100

# %%
fig = px.line(carteira, x = carteira.index, y=carteira['MinVol'])

# Edit the layout
fig.update_layout(title='Carteira Teórica - Gerada por Black-Litterman e Relabanceamento Trimestral',
                   xaxis_title='Data',
                   yaxis_title='Patrimônio Líquido')

fig.show()
